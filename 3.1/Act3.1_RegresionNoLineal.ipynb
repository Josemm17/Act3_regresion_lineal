# %% [markdown]
# # **Actividad 3.1 (Regresión No Lineal)**

# %% [markdown]
# ## Carga de archivos y limpieza de datos

# %%
#Cargamos librerias
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.special as special
from scipy.optimize import curve_fit
import seaborn as sns
from sklearn.metrics import r2_score

df=pd.read_csv("Rio_limpio.csv")

# %%
vars_num=df.select_dtypes(include=['float64', 'int64','float','int'])

Corr_factors=vars_num.corr()

#Obtener el valor absoluto
Corr_factors_abosluto=abs(Corr_factors)

#Ajustar el heatmap con los coeficientes de correlacion
Heat_map=sns.heatmap(Corr_factors_abosluto, cmap="coolwarm")
Heat_map
# Out:
# <Axes: >

# %% [markdown]
# ## Elegir 2 modelos de correlación No lineal y Analizar la correlación que existe entre las siguientes variables:
#
# ->host_response_rate
#
# ->host_acceptance_rate
#
# ->host_total_listings_count
#
# ->accommodates
#
# ->reviews_per_month
#
# ->price

# %% [markdown]
# ### host_response_rate

# %%
#Declaramos las variables dependientes e independientes para la regresión No lineal
Vars_Indep= df[['availability_30']]
Var_Dep= df['host_response_rate']

#Redefinimos las variables 
x= Vars_Indep
y= Var_Dep

def  func1 (x, a, b, c):
    return a*x**2 + b*x + c #("Función cuadrática")

#Ajustamos los parámetros de la función curve_fit
parametros1, covs = curve_fit(func1, df['availability_30'], df['host_response_rate'])

# Predicciones
y_pred1 = func1(x, *parametros1)


#Graficamos las predicciones y los datos originales para realizar la comparación
plt.plot(x, y, 'bo', label="y-original")
plt.plot(x, y_pred1, label="y-predecida con y=a*x**2 + b*x + c")
plt.xlabel('x')
plt.ylabel('y')
plt.legend(loc='best', fancybox=True, shadow=True)
plt.grid(True)
plt.show() 

#Calculamos el coeficiente de determinación del modelo
R2_Modelo1 = r2_score(y, y_pred1) 
print(R2_Modelo1)

#Calculamos el coeficiente de correlación del modelo
R = np.sqrt(abs(R2_Modelo1))
print(R)
# Out:
# 0.0498550307449086
# 0.22328240133272617

# %%
#Declaramos las variables dependientes e independientes para la regresión No lineal
Vars_Indep= df[['availability_30']]
Var_Dep= df['host_response_rate']

#Redefinimos las variables 
x= Vars_Indep
y= Var_Dep

def  func1 (x, a, b, c):
    return a*np.abs(x) + b*x + c #(Función Valor absoluto)


#Ajustamos los parámetros de la función curve_fit
parametros1, covs = curve_fit(func1, df['availability_30'], df['host_response_rate'])

# Predicciones
y_pred1 = func1(x, *parametros1)


#Graficamos las predicciones y los datos originales para realizar la comparación
plt.plot(x, y, 'bo', label="y-original")
plt.plot(x, y_pred1, label="y-predecida con y=a*np.abs(x) + b*x + c")
plt.xlabel('x')
plt.ylabel('y')
plt.legend(loc='best', fancybox=True, shadow=True)
plt.grid(True)
plt.show() 

#Calculamos el coeficiente de determinación del modelo
R2_Modelo1 = r2_score(y, y_pred1) 
print(R2_Modelo1)

#Calculamos el coeficiente de correlación del modelo
R = np.sqrt(abs(R2_Modelo1))
print(R)
# Out:
# 0.0196954973415282
# 0.14034064750288208

# %% [markdown]
# ### host_acceptance_rate

# %%
#Declaramos las variables dependientes e independientes para la regresión No lineal
Vars_Indep= df[['availability_30']]
Var_Dep= df['host_acceptance_rate']

#Redefinimos las variables 
x= Vars_Indep
y= Var_Dep

def  func1 (x, a, b, c):
    return a*x**2 + b*x + c #("Función cuadrática")

#Ajustamos los parámetros de la función curve_fit
parametros1, covs = curve_fit(func1, df['availability_30'], df['host_acceptance_rate'])

# Predicciones
y_pred1 = func1(x, *parametros1)


#Graficamos las predicciones y los datos originales para realizar la comparación
plt.plot(x, y, 'bo', label="y-original")
plt.plot(x, y_pred1, label="y-predecida con y=a*x**2 + b*x + c")
plt.xlabel('x')
plt.ylabel('y')
plt.legend(loc='best', fancybox=True, shadow=True)
plt.grid(True)
plt.show() 

#Calculamos el coeficiente de determinación del modelo
R2_Modelo1 = r2_score(y, y_pred1) 
print(R2_Modelo1)

#Calculamos el coeficiente de correlación del modelo
R = np.sqrt(abs(R2_Modelo1))
print(R)
# Out:
# 0.053154149499971104
# 0.23055183690435238

# %%
#Declaramos las variables dependientes e independientes para la regresión No lineal
Vars_Indep= df[['availability_30']]
Var_Dep= df['host_acceptance_rate']

#Redefinimos las variables 
x= Vars_Indep
y= Var_Dep

def  func1 (x, a, b, c):
    return a*np.abs(x) + b*x + c #(Función Valor absoluto)


#Ajustamos los parámetros de la función curve_fit
parametros1, covs = curve_fit(func1, df['availability_30'], df['host_acceptance_rate'])

# Predicciones
y_pred1 = func1(x, *parametros1)


#Graficamos las predicciones y los datos originales para realizar la comparación
plt.plot(x, y, 'bo', label="y-original")
plt.plot(x, y_pred1, label="y-predecida con y=a*np.abs(x) + b*x + c")
plt.xlabel('x')
plt.ylabel('y')
plt.legend(loc='best', fancybox=True, shadow=True)
plt.grid(True)
plt.show() 

#Calculamos el coeficiente de determinación del modelo
R2_Modelo1 = r2_score(y, y_pred1) 
print(R2_Modelo1)

#Calculamos el coeficiente de correlación del modelo
R = np.sqrt(abs(R2_Modelo1))
print(R)
# Out:
# 0.03997215048230607
# 0.19993036408286277

# %% [markdown]
# ### host_total_listings_count

# %%
#Declaramos las variables dependientes e independientes para la regresión No lineal
Vars_Indep= df[['price']]
Var_Dep= df['host_total_listings_count']

#Redefinimos las variables 
x= Vars_Indep
y= Var_Dep

def  func1 (x, a, b, c):
    return a/b*x**2 + c*x #(Función polinomial inversa)


#Ajustamos los parámetros de la función curve_fit
parametros1, covs = curve_fit(func1, df['price'], df['host_total_listings_count'])

# Predicciones
y_pred1 = func1(x, *parametros1)


#Graficamos las predicciones y los datos originales para realizar la comparación
plt.plot(x, y, 'bo', label="y-original")
plt.plot(x, y_pred1, label="y-predecida con y=a/b*x**2 + c*x")
plt.xlabel('x')
plt.ylabel('y')
plt.legend(loc='best', fancybox=True, shadow=True)
plt.grid(True)
plt.show() 

#Calculamos el coeficiente de determinación del modelo
R2_Modelo1 = r2_score(y, y_pred1) 
print(R2_Modelo1)

#Calculamos el coeficiente de correlación del modelo
R = np.sqrt(abs(R2_Modelo1))
print(R)
# Out:
# -0.09485235289072658
# 0.3079810917746844

# %%
#Declaramos las variables dependientes e independientes para la regresión No lineal
Vars_Indep= df[['price']]
Var_Dep= df['host_total_listings_count']

#Redefinimos las variables 
x= Vars_Indep
y= Var_Dep

def  func1 (x, a, b, c):
    return a*x + b*x + c*x #(Función lineal con producto de coeficientes)


#Ajustamos los parámetros de la función curve_fit
parametros1, covs = curve_fit(func1, df['price'], df['host_total_listings_count'])

# Predicciones
y_pred1 = func1(x, *parametros1)


#Graficamos las predicciones y los datos originales para realizar la comparación
plt.plot(x, y, 'bo', label="y-original")
plt.plot(x, y_pred1, label="y-predecida con y=a*x + b*x + c*x")
plt.xlabel('x')
plt.ylabel('y')
plt.legend(loc='best', fancybox=True, shadow=True)
plt.grid(True)
plt.show() 

#Calculamos el coeficiente de determinación del modelo
R2_Modelo1 = r2_score(y, y_pred1) 
print(R2_Modelo1)

#Calculamos el coeficiente de correlación del modelo
R = np.sqrt(abs(R2_Modelo1))
print(R)
# Out:
# -0.24467519428958995
# 0.49464653469885944

# %% [markdown]
# ### accommodates

# %%
#Declaramos las variables dependientes e independientes para la regresión No lineal
Vars_Indep= df[['price']]
Var_Dep= df['accommodates']

#Redefinimos las variables 
x= Vars_Indep
y= Var_Dep

def  func1 (x, a, b, c):
    return a/b*x**2 + c*x #(Función polinomial inversa)


#Ajustamos los parámetros de la función curve_fit
parametros1, covs = curve_fit(func1, df['price'], df['accommodates'])

# Predicciones
y_pred1 = func1(x, *parametros1)


#Graficamos las predicciones y los datos originales para realizar la comparación
plt.plot(x, y, 'bo', label="y-original")
plt.plot(x, y_pred1, label="y-predecida con y=a/b*x**2 + c*x")
plt.xlabel('x')
plt.ylabel('y')
plt.legend(loc='best', fancybox=True, shadow=True)
plt.grid(True)
plt.show() 

#Calculamos el coeficiente de determinación del modelo
R2_Modelo1 = r2_score(y, y_pred1) 
print(R2_Modelo1)

#Calculamos el coeficiente de correlación del modelo
R = np.sqrt(abs(R2_Modelo1))
print(R)
# Out:
# -0.037901674013276265
# 0.19468352270615064

# %%
#Declaramos las variables dependientes e independientes para la regresión No lineal
Vars_Indep= df[['price']]
Var_Dep= df['accommodates']

#Redefinimos las variables 
x= Vars_Indep
y= Var_Dep

def  func1 (x, a, b, c):
    return (a*x**2 + b)/ c*x #(Función cociente entre polinomios)

#Ajustamos los parámetros de la función curve_fit
parametros1, covs = curve_fit(func1, df['price'], df['accommodates'])

# Predicciones
y_pred1 = func1(x, *parametros1)


#Graficamos las predicciones y los datos originales para realizar la comparación
plt.plot(x, y, 'bo', label="y-original")
plt.plot(x, y_pred1, label="y-predecida con y=(a*x**2 + b)/ c*x")
plt.xlabel('x')
plt.ylabel('y')
plt.legend(loc='best', fancybox=True, shadow=True)
plt.grid(True)
plt.show() 

#Calculamos el coeficiente de determinación del modelo
R2_Modelo1 = r2_score(y, y_pred1) 
print(R2_Modelo1)

#Calculamos el coeficiente de correlación del modelo
R = np.sqrt(abs(R2_Modelo1))
print(R)
# Out:
# -0.1564306706814369
# 0.3955131738405649

# %% [markdown]
# ### reviews_per_month

# %%
#Declaramos las variables dependientes e independientes para la regresión No lineal
Vars_Indep= df[['price']]
Var_Dep= df['reviews_per_month']

#Redefinimos las variables 
x= Vars_Indep
y= Var_Dep

def  func1 (x, a, b, c):
    return a/b*x**2 + c*x #(Función polinomial inversa)


#Ajustamos los parámetros de la función curve_fit
parametros1, covs = curve_fit(func1, df['price'], df['reviews_per_month'])

# Predicciones
y_pred1 = func1(x, *parametros1)


#Graficamos las predicciones y los datos originales para realizar la comparación
plt.plot(x, y, 'bo', label="y-original")
plt.plot(x, y_pred1, label="y-predecida con y=a/b*x**2 + c*x")
plt.xlabel('x')
plt.ylabel('y')
plt.legend(loc='best', fancybox=True, shadow=True)
plt.grid(True)
plt.show() 

#Calculamos el coeficiente de determinación del modelo
R2_Modelo1 = r2_score(y, y_pred1) 
print(R2_Modelo1)

#Calculamos el coeficiente de correlación del modelo
R = np.sqrt(abs(R2_Modelo1))
print(R)
# Out:
# -0.20833478550344564
# 0.45643705535752205

# %%
#Declaramos las variables dependientes e independientes para la regresión No lineal
Vars_Indep= df[['price']]
Var_Dep= df['reviews_per_month']

#Redefinimos las variables 
x= Vars_Indep
y= Var_Dep

def  func1 (x, a, b, c):
    return (a*x**2 + b)/ c*x #(Función cociente entre polinomios)


#Ajustamos los parámetros de la función curve_fit
parametros1, covs = curve_fit(func1, df['price'], df['reviews_per_month'])

# Predicciones
y_pred1 = func1(x, *parametros1)


#Graficamos las predicciones y los datos originales para realizar la comparación
plt.plot(x, y, 'bo', label="y-original")
plt.plot(x, y_pred1, label="y-predecida con y=(a*x**2 + b)/ c*x")
plt.xlabel('x')
plt.ylabel('y')
plt.legend(loc='best', fancybox=True, shadow=True)
plt.grid(True)
plt.show() 

#Calculamos el coeficiente de determinación del modelo
R2_Modelo1 = r2_score(y, y_pred1) 
print(R2_Modelo1)

#Calculamos el coeficiente de correlación del modelo
R = np.sqrt(abs(R2_Modelo1))
print(R)
# Out:
# -0.3076862126875062
# 0.5546947022349377

# %% [markdown]
# ### price

# %%
#Declaramos las variables dependientes e independientes para la regresión No lineal
Vars_Indep= df[['bathrooms']]
Var_Dep= df['price']

#Redefinimos las variables 
x= Vars_Indep
y= Var_Dep

def  func1 (x, a, b, c):
    return a/b*x**2 + c*x #(Función polinomial inversa)


#Ajustamos los parámetros de la función curve_fit
parametros1, covs = curve_fit(func1, df['bathrooms'], df['price'])

# Predicciones
y_pred1 = func1(x, *parametros1)


#Graficamos las predicciones y los datos originales para realizar la comparación
plt.plot(x, y, 'bo', label="y-original")
plt.plot(x, y_pred1, label="y-predecida con y=a/b*x**2 + c*x")
plt.xlabel('x')
plt.ylabel('y')
plt.legend(loc='best', fancybox=True, shadow=True)
plt.grid(True)
plt.show() 

#Calculamos el coeficiente de determinación del modelo
R2_Modelo1 = r2_score(y, y_pred1) 
print(R2_Modelo1)

#Calculamos el coeficiente de correlación del modelo
R = np.sqrt(abs(R2_Modelo1))
print(R)
# Out:
# 0.11657669123030145
# 0.34143328957543295

# %%
#Declaramos las variables dependientes e independientes para la regresión No lineal
Vars_Indep= df[['price']]
Var_Dep= df['reviews_per_month']

#Redefinimos las variables 
x= Vars_Indep
y= Var_Dep

def  func1 (x, a, b, c):
    return (a*x**2 + b)/ c*x #(Función cociente entre polinomios)


#Ajustamos los parámetros de la función curve_fit
parametros1, covs = curve_fit(func1, df['price'], df['reviews_per_month'])

# Predicciones
y_pred1 = func1(x, *parametros1)


#Graficamos las predicciones y los datos originales para realizar la comparación
plt.plot(x, y, 'bo', label="y-original")
plt.plot(x, y_pred1, label="y-predecida con y=(a*x**2 + b)/ c*x")
plt.xlabel('x')
plt.ylabel('y')
plt.legend(loc='best', fancybox=True, shadow=True)
plt.grid(True)
plt.show() 

#Calculamos el coeficiente de determinación del modelo
R2_Modelo1 = r2_score(y, y_pred1) 
print(R2_Modelo1)

#Calculamos el coeficiente de correlación del modelo
R = np.sqrt(abs(R2_Modelo1))
print(R)
# Out:
# -0.3076862126875062
# 0.5546947022349377
